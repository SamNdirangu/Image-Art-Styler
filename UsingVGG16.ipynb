# %% [markdown]
# <a href="https://colab.research.google.com/github/SamNdirangu/Image-Art-Styler/blob/master/UsingVGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

import skimage.io
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image


from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input, decode_predictions

# %%
model = VGG16(weights='imagenet', include_top=True)

layers= dict([(layer.name,layer.output) for layer in model.layers])

# %%
model.count_params()
# Out:
# 138357544

# %%
image = Image.open('cow.jpg')
image = image.resize((224, 224))
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FE69EB3AE48>

# %%
#Convert it into an array
x = np.asarray(image, dtype = 'float32')

#Covert it to a list of items
x = np.expand_dims(x, axis = 0)
# Pre-process the input to match the training data

x= preprocess_input(x)

# %%
#Classifyour test image

pred = model.predict(x)

print('Predicted: ', decode_predictions(pred, top = 3)[0])
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step
# Predicted:  [('n02389026', 'sorrel', 0.5463116), ('n02403003', 'ox', 0.44641328), ('n03868242', 'oxcart', 0.0030991759)]
